# %% [markdown]
# # Capstone Project - Battle of Neighborhoods

# %% [markdown]
# ## Finding the best area to set up a small boutque cafe in Manhattan, NY

# %% [markdown]
# ### Load Libraries

# %%
# !conda install -c conda-forge geopy --yes
#!conda install -c conda-forge folium=0.5.0 --yes

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans
#import folium # map rendering library
print("Libraries imported")
# Out:
# Libraries imported

# %% [markdown]
# ### Data

# %% [markdown]
# Load New York data json file and read to a DataFrame

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset #import json file
print('Data downloaded!')

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
newyork_data

# %%
neighborhoods_data = newyork_data['features']
neighborhoods_data[0]

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

#create dataframe
neighborhoods_df = pd.DataFrame(columns=column_names)
neighborhoods_df

# %%
for data in neighborhoods_data:
    borough = neighborhood_name=data['properties']['borough']
    neighborhood_name = data['properties']['name']
    
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods_df=neighborhoods_df.append({'Borough': borough,
                                              'Neighborhood': neighborhood_name,
                                              'Latitude': neighborhood_lat,
                                              'Longitude':neighborhood_lon},ignore_index=True)
    
neighborhoods_df.head()

# %% [markdown]
# To confirm the data is correct we will check there is 5 Boroughs and 306 neighborhoods

# %%
print('This dataframe has {} boroughs and {} neighborhoods in New York City'.format(len(neighborhoods_df['Borough'].unique()),neighborhoods_df.shape[0]))
# Out:
# This dataframe has 5 boroughs and 306 neighborhoods in New York City

# %% [markdown]
# As we are only looking at Manhattan for this project we will create a new dataframe with only Manhattan Data

# %%
manhattan_df=neighborhoods_df[neighborhoods_df['Borough']=='Manhattan'].reset_index(drop=True)
manhattan_df.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude
# 0  Manhattan         Marble Hill  40.876551 -73.910660
# 1  Manhattan           Chinatown  40.715618 -73.994279
# 2  Manhattan  Washington Heights  40.851903 -73.936900
# 3  Manhattan              Inwood  40.867684 -73.921210
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688

# %% [markdown]
# Read in New York Crime data

# %%
import csv

# %%
crime_data=pd.read_csv('https://data.cityofnewyork.us/api/views/qgea-i56i/rows.csv?accessType=DOWNLOAD')
crime_data.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (18,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   325341655   02/11/2015     15:00:00          NaN          NaN
# 1   393816841   03/17/2012     10:30:00   03/17/2012     11:00:00
# 2   802896158   10/27/2016     13:48:00   11/03/2016     13:49:00
# 3   633812343   11/27/2014     19:00:00   11/27/2014     22:30:00
# 4   300349533   12/11/2013     13:30:00   12/11/2013     14:15:00
#
#    ADDR_PCT_CD      RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 0         73.0  02/11/2015    359  OFFENSES AGAINST PUBLIC ADMINI  749.0
# 1         69.0  03/17/2012    344    ASSAULT 3 & RELATED OFFENSES  114.0
# 2         71.0  11/03/2016    578                   HARRASSMENT 2  638.0
# 3        112.0  11/28/2014    104                            RAPE  157.0
# 4         24.0  12/12/2013    109                   GRAND LARCENY  438.0
#
#                                              PD_DESC CRM_ATPT_CPTD_CD  \
# 0                     VIOLATION OF ORDER OF PROTECTI        COMPLETED
# 1                                OBSTR BREATH/CIRCUL        COMPLETED
# 2                              HARASSMENT,SUBD 3,4,5        COMPLETED
# 3                                             RAPE 1        COMPLETED
# 4  LARCENY,GRAND FROM BUILDING (NON-RESIDENCE) UN...        COMPLETED
#
#     LAW_CAT_CD    BORO_NM LOC_OF_OCCUR_DESC               PREM_TYP_DESC  \
# 0  MISDEMEANOR   BROOKLYN            INSIDE  RESIDENCE - PUBLIC HOUSING
# 1  MISDEMEANOR   BROOKLYN            INSIDE             RESIDENCE-HOUSE
# 2    VIOLATION   BROOKLYN            INSIDE               PUBLIC SCHOOL
# 3       FELONY     QUEENS            INSIDE      RESIDENCE - APT. HOUSE
# 4       FELONY  MANHATTAN            INSIDE       DOCTOR/DENTIST OFFICE
#
#             JURIS_DESC  JURISDICTION_CODE PARKS_NM HADEVELOPT HOUSING_PSA  \
# 0  N.Y. HOUSING POLICE                2.0      NaN     TILDEN         405
# 1     N.Y. POLICE DEPT                0.0      NaN        NaN         NaN
# 2     N.Y. POLICE DEPT                0.0      NaN        NaN         NaN
# 3     N.Y. POLICE DEPT                0.0      NaN        NaN         NaN
# 4     N.Y. POLICE DEPT                0.0      NaN        NaN         NaN
#
#    X_COORD_CD  Y_COORD_CD SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX  \
# 0   1009656.0    181287.0          25-44           BLACK        M
# 1   1014035.0    174133.0            NaN             NaN      NaN
# 2   1000222.0    179282.0            <18           BLACK        M
# 3   1025420.0    202485.0          25-44  WHITE HISPANIC        M
# 4    992848.0    228356.0            NaN             NaN      NaN
#
#    TRANSIT_DISTRICT   Latitude  Longitude                        Lat_Lon  \
# 0               NaN  40.664239 -73.908425  (40.664239422, -73.908425011)
# 1               NaN  40.644590 -73.892672  (40.644589618, -73.892672426)
# 2               NaN  40.658758 -73.942435  (40.658758183, -73.942434788)
# 3               NaN  40.722364 -73.851474  (40.722363687, -73.851473894)
# 4               NaN  40.793465 -73.968950  (40.793464597, -73.968949638)
#
#                 PATROL_BORO STATION_NAME VIC_AGE_GROUP VIC_RACE VIC_SEX
# 0   PATROL BORO BKLYN NORTH          NaN           <18    BLACK       M
# 1   PATROL BORO BKLYN SOUTH          NaN         45-64    BLACK       F
# 2   PATROL BORO BKLYN SOUTH          NaN         18-24    BLACK       M
# 3  PATROL BORO QUEENS NORTH          NaN         25-44    WHITE       F
# 4     PATROL BORO MAN NORTH          NaN         45-64    WHITE       F

# %%
crime_data.shape
# Out:
# (6983207, 35)

# %%
crime_data.dtypes
# Out:
# CMPLNT_NUM             int64
# CMPLNT_FR_DT          object
# CMPLNT_FR_TM          object
# CMPLNT_TO_DT          object
# CMPLNT_TO_TM          object
# ADDR_PCT_CD          float64
# RPT_DT                object
# KY_CD                  int64
# OFNS_DESC             object
# PD_CD                float64
# PD_DESC               object
# CRM_ATPT_CPTD_CD      object
# LAW_CAT_CD            object
# BORO_NM               object
# LOC_OF_OCCUR_DESC     object
# PREM_TYP_DESC         object
# JURIS_DESC            object
# JURISDICTION_CODE    float64
# PARKS_NM              object
# HADEVELOPT            object
# HOUSING_PSA           object
# X_COORD_CD           float64
# Y_COORD_CD           float64
# SUSP_AGE_GROUP        object
# SUSP_RACE             object
# SUSP_SEX              object
# TRANSIT_DISTRICT     float64
# Latitude             float64
# Longitude            float64
# Lat_Lon               object
# PATROL_BORO           object
# STATION_NAME          object
# VIC_AGE_GROUP         object
# VIC_RACE              object
# VIC_SEX               object
# dtype: object

# %% [markdown]
# We will only include the following columns for the analysis
#
# CMPLNT_FR_DT - Complaint first reported date  <br>
# LAW_CAT_CD - Law category  <br>
# BORO_NM - Borough Name  <br>
# Latitide- Latitude  <br>
# Longitude- Longitude

# %%
crime_df = crime_data[['CMPLNT_FR_DT','LAW_CAT_CD','BORO_NM','Latitude','Longitude']]
crime_df.head()
# Out:
#   CMPLNT_FR_DT   LAW_CAT_CD    BORO_NM   Latitude  Longitude
# 0   02/11/2015  MISDEMEANOR   BROOKLYN  40.664239 -73.908425
# 1   03/17/2012  MISDEMEANOR   BROOKLYN  40.644590 -73.892672
# 2   10/27/2016    VIOLATION   BROOKLYN  40.658758 -73.942435
# 3   11/27/2014       FELONY     QUEENS  40.722364 -73.851474
# 4   12/11/2013       FELONY  MANHATTAN  40.793465 -73.968950

# %% [markdown]
# Filter crime_df to only include crimes in Manhattan

# %%
crime_df=crime_df[crime_df['BORO_NM']=='MANHATTAN']
crime_df.head()
crime_df.shape
# Out:
# (98693, 5)

# %% [markdown]
# Filter crime_df to only inlcude felony and misdemeanor crimes

# %%
crime_df=crime_df[crime_df.LAW_CAT_CD.isin(['FELONY', 'MISDEMEANOR'])]
crime_df.shape
# Out:
# (1497457, 5)

# %% [markdown]
# Filter crime_df to only include crimes from 2019

# %%
crime_df=crime_df.dropna(subset=['CMPLNT_FR_DT'])
crime_df.shape
# Out:
# (1497334, 5)

# %%
crime_df=crime_df[crime_df['CMPLNT_FR_DT'].str.contains("2019")]

# %%
crime_df.shape
# Out:
# (98693, 5)

# %%
crime_df.head(10)
# Out:
#         CMPLNT_FR_DT   LAW_CAT_CD    BORO_NM   Latitude  Longitude
# 1830027   01/02/2019       FELONY  MANHATTAN  40.773332 -73.961074
# 1830636   01/03/2019       FELONY  MANHATTAN  40.787567 -73.943132
# 1832787   01/06/2019  MISDEMEANOR  MANHATTAN  40.765024 -73.984836
# 1832815   01/09/2019  MISDEMEANOR  MANHATTAN  40.815732 -73.945420
# 1832851   01/14/2019       FELONY  MANHATTAN  40.794515 -73.966324
# 1832873   01/18/2019  MISDEMEANOR  MANHATTAN  40.723659 -73.991022
# 1832897   01/27/2019  MISDEMEANOR  MANHATTAN  40.732356 -73.984941
# 1832910   01/31/2019  MISDEMEANOR  MANHATTAN  40.749780 -73.987781
# 1832917   01/29/2019  MISDEMEANOR  MANHATTAN  40.823575 -73.937675
# 1832941   02/04/2019  MISDEMEANOR  MANHATTAN  40.710783 -73.996632

# %% [markdown]
# Load Subway Entrances JSON Data

# %%
content = requests.get("https://data.cityofnewyork.us/resource/he7q-3hwy.json")
json = json.loads(content.content)

# %%
json
# Out:
# [{'objectid': '1734',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Birchall Ave & Sagamore St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.86835600032798, 40.84916900104506]},
#   'line': '2-5'},
#  {'objectid': '1735',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Birchall Ave & Sagamore St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.86821300022677, 40.84912800131844]},
#   'line': '2-5'},
#  {'objectid': '1736',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Morris Park Ave & 180th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.87349900050798, 40.84122300105249]},
#   'line': '2-5'},
#  {'objectid': '1737',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Morris Park Ave & 180th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.8728919997833, 40.84145300067447]},
#   'line': '2-5'},
#  {'objectid': '1738',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Boston Rd & 178th St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.
& Roosevelt Ave at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.88402800010363, 40.747797001025944]},
#   'line': '7'},
#  {'objectid': '1800',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '69th St & Roosevelt Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.89626799980942, 40.746509000982186]},
#   'line': '7'},
#  {'objectid': '1801',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '69th St & Roosevelt Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.89639599982912, 40.74614800114902]},
#   'line': '7'},
#  {'objectid': '1802',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '61st St & Roosevelt Ave at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.90324800020599, 40.745531000834546]},
#   'line': '7'},
#  {'objectid': '1803',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '61st St & Roosevelt Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9030630001761, 40.74571700080551]},
#   'line': '7'},
#  {'objectid': '1804',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '61st St & Roosevelt Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.90323399968668, 40.74569200063943]},
#   'line': '7'},
#  {'objectid': '1805',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '52nd St & Roosevelt Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.91300299979955, 40.74393300069892]},
#   'line': '7'},
#  {'objectid': '1806',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '52nd St & Roosevelt Ave at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.91308000030901, 40.74406700117441]},
#   'line': '7'},
#  {'objectid': '1807',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '53rd St & Roosevelt Ave at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.91128200023064, 40.74445300048593]},
#   'line': '7'},
#  {'objectid': '1808',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '53rd St & Roosevelt Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.91129400006578, 40.74459000117725]},
#   'line': '7'},
#  {'objectid': '1809',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '46th St & Queens Blvd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9186010004369, 40.743064000975544]},
#   'line': '7'},
#  {'objectid': '1810',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '46th St & Queens Blvd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.91856399986699, 40.74321700071532]},
#   'line': '7'},
#  {'objectid': '1811',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '46th St & Queens Blvd at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.91884800020249, 40.74310500067605]},
#   'line': '7'},
#  {'objectid': '1812',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '46th St & Queens Blvd at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.91881300055115, 40.743240000765105]},
#   'line': '7'},
#  {'objectid': '1813',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '40th St & Queens Blvd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.92416100027046, 40.74371000112609]},
#   'line': '7'},
#  {'objectid': '1814',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '40th St & Queens Blvd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.92411200014045, 40.74388200082643]},
#   'line': '7'},
#  {'objectid': '1815',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '40th St & Queens Blvd at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.92441700024656, 40.74374300100013]},
#   'line': '7'},
#  {'objectid': '1816',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '40th St & Queens Blvd at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.92438500038787, 40.74391100111205]},
#   'line': '7'},
#  {'objectid': '1817',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '33rd St & Queens Blvd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.93157000009163, 40.74456800061942]},
#   'line': '7'},
#  {'objectid': '1818',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '33rd St & Queens Blvd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.93153300052721, 40.744724000461275]},
#   'line': '7'},
#  {'objectid': '1819',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '33rd St & Queens Blvd at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.93182900025066, 40.74459400056049]},
#   'line': '7'},
#  {'objectid': '1820',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '33rd St & Queens Blvd at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9317939996055, 40.74476300048575]},
#   'line': '7'},
#  {'objectid': '1821',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Queens Plaza North & 27th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9396710002236, 40.7508350011798]},
#   'line': 'N-Q-7'},
#  {'objectid': '1822',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Queens Plaza South & 27th St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.940244999736, 40.750302000858184]},
#   'line': 'N-Q-7'},
#  {'objectid': '1823',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '23rd St & 45th Rd at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.94571300016653, 40.746308001163634]},
#   'line': 'E-G-M-7'},
#  {'objectid': '1824',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '23rd St & 45th Rd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.94534899958121, 40.74613000057653]},
#   'line': 'E-G-M-7'},
#  {'objectid': '1825',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '23rd St & 45th Rd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.94532200035314, 40.74623200075596]},
#   'line': 'E-G-M-7'},
#  {'objectid': '1826',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '21st St & 49th Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.94860899952165, 40.742500001189924]},
#   'line': '7'},
#  {'objectid': '1827',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '21st St & 49th Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.94810999980871, 40.74240500087813]},
#   'line': '7'},
#  {'objectid': '1828',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '21st St & 49th Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9481950003783, 40.742422001095164]},
#   'line': '7'},
#  {'objectid': '1829',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Vernon Blvd & 50th Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9538929998818, 40.74275900114013]},
#   'line': '7'},
#  {'objectid': '1830',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Vernon Blvd & 50th Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.95395500036102, 40.74280300130392]},
#   'line': '7'},
#  {'objectid': '1831',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '5th Ave & 42nd St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98112999996737, 40.753409001192345]},
#   'line': 'B-D-F-M-7'},
#  {'objectid': '1832',
#   'url': 'http://web.mta.info/nyct/service/',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.01314899949054, 40.702033000801315]},
#   'line': 'R-1'},
#  {'objectid': '1833',
#   'url': 'http://web.mta.info/nyct/service/',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.01314899949054, 40.702033000801315]},
#   'line': 'R-1'},
#  {'objectid': '1834',
#   'url': 'http://web.mta.info/nyct/service/',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.01339699956122, 40.701961000593066]},
#   'line': 'R-1'},
#  {'objectid': '1835',
#   'url': 'http://web.mta.info/nyct/service/',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.01339699956122, 40.701961000593066]},
#   'line': 'R-1'},
#  {'objectid': '1836',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '3rd Ave & 60th St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9663399998183, 40.76209200118288]},
#   'line': 'N-Q-R-4-5-6'},
#  {'objectid': '1837',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '3rd Ave & 60th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.96615499958986, 40.76235300051639]},
#   'line': 'N-Q-R-4-5-6'},
#  {'objectid': '1838',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '3rd Ave & 60th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.96610500024993, 40.76199600064206]},
#   'line': 'N-Q-R-4-5-6'},
#  {'objectid': '1839',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '3rd Ave & 60th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.96591800006873, 40.76225500079114]},
#   'line': 'N-Q-R-4-5-6'},
#  {'objectid': '1840',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Grand Army Plaza & Central Park South at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97422800020375, 40.76459900091597]},
#   'line': 'N-Q-R'},
#  {'objectid': '1841',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Grand Army Plaza & Central Park South at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9741909995507, 40.764935001318285]},
#   'line': 'N-Q-R'},
#  {'objectid': '1842',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Grand Army Plaza & Central Park South at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97399800052692, 40.76485900130548]},
#   'line': 'N-Q-R'},
#  {'objectid': '1843',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '7th Ave & 55th St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98127799942094, 40.76425800051672]},
#   'line': 'N-Q-R'},
#  {'objectid': '1844',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '7th Ave & 55th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98080300054961, 40.76405700096569]},
#   'line': 'N-Q-R'},
#  {'objectid': '1845',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '7th Ave & 55th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98116699968199, 40.76437700115304]},
#   'line': 'N-Q-R'},
#  {'objectid': '1846',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '7th Ave & 55th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98068299949864, 40.76417900101943]},
#   'line': 'N-Q-R'},
#  {'objectid': '1847',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '7th Ave & 49th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98338800031021, 40.76045400110487]},
#   'line': 'N-Q-R'},
#  {'objectid': '1848',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '7th Ave & 47th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98441200013421, 40.75903000051641]},
#   'line': 'N-Q-R'},
#  {'objectid': '1849',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 47th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9848840002975, 40.759513000523555]},
#   'line': 'N-Q-R'},
#  {'objectid': '1850',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '7th Ave & 47th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98470900013602, 40.7593840008346]},
#   'line': 'N-Q-R'},
#  {'objectid': '1851',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '7th Ave & 49th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.983566999586, 40.760297001282645]},
#   'line': 'N-Q-R'},
#  {'objectid': '1852',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 40th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98668000023042, 40.75417200053055]},
#   'line': 'A-C-E-N-Q-R-S-1-2-3-7'},
#  {'objectid': '1853',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 40th St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98709699980543, 40.754335000754985]},
#   'line': 'A-C-E-N-Q-R-S-1-2-3-7'},
#  {'objectid': '1854',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 40th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98662299991872, 40.75430100123342]},
#   'line': 'A-C-E-N-Q-R-S-1-2-3-7'},
#  {'objectid': '1855',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 40th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98710799954023, 40.754507001220134]},
#   'line': 'A-C-E-N-Q-R-S-1-2-3-7'},
#  {'objectid': '1856',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '6th Ave & 34th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9876200005048, 40.74959000083694]},
#   'line': 'B-D-F-M-N-Q-R'},
#  {'objectid': '1857',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '6th Ave & 34th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98749500039362, 40.74989100127905]},
#   'line': 'B-D-F-M-N-Q-R'},
#  {'objectid': '1858',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 32nd St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98797600009624, 40.74829400133664]},
#   'line': 'B-D-F-M-N-Q-R'},
#  {'objectid': '1859',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 32nd St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98828799998653, 40.74847700103222]},
#   'line': 'B-D-F-M-N-Q-R'},
#  {'objectid': '1860',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 28th St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98892300054607, 40.745281001027514]},
#   'line': 'N-R'},
#  {'objectid': '1861',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 28th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98901000023109, 40.74548800070196]},
#   'line': 'N-R'},
#  {'objectid': '1862',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 22nd St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98921700007142, 40.740643000678176]},
#   'line': 'N-R'},
#  {'objectid': '1863',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '5th Ave & 22nd St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98963900052017, 40.74120800048306]},
#   'line': 'N-R'},
#  {'objectid': '1864',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 23rd St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98942800017326, 40.7419130008876]},
#   'line': 'N-R'},
#  {'objectid': '1865',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 22nd St at NW corner (exit only)',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9896320000055, 40.74075800113276]},
#   'line': 'N-R'},
#  {'objectid': '1866',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 16th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99060299993691, 40.736339000909425]},
#   'line': 'L-N-Q-R-4-5-6'},
#  {'objectid': '1867',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 16th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99044699972468, 40.7365230005194]},
#   'line': 'L-N-Q-R-4-5-6'},
#  {'objectid': '1868',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & Waverly Pl at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99305100039543, 40.72967800077502]},
#   'line': 'N-R'},
#  {'objectid': '1869',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 8th Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99273699962603, 40.73064200093977]},
#   'line': 'N-R'},
#  {'objectid': '1870',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 8th Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99261999986997, 40.73059200087505]},
#   'line': 'N-R'},
#  {'objectid': '1871',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 8th Ave at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99251700000923, 40.73071600054057]},
#   'line': 'N-R'},
#  {'objectid': '1872',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & 8th Ave at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99264099990762, 40.730773000808504]},
#   'line': 'N-R'},
#  {'objectid': '1873',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & Prince St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99795699956412, 40.724260000652734]},
#   'line': 'N-R'},
#  {'objectid': '1874',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & Prince St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99787499970364, 40.72434400046753]},
#   'line': 'N-R'},
#  {'objectid': '1875',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & Canal St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.0019299996069, 40.71958500129559]},
#   'line': 'J-N-Q-R-Z-6'},
#  {'objectid': '1876',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & Canal St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.00201900001107, 40.71966000052618]},
#   'line': 'J-N-Q-R-Z-6'},
#  {'objectid': '1877',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & Canal St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.00215800047437, 40.71940800114969]},
#   'line': 'J-N-Q-R-Z-6'},
#  {'objectid': '1878',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & Canal St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.00223600009556, 40.719460000499545]},
#   'line': 'J-N-Q-R-Z-6'},
#  {'objectid': '1',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '15th St & Kings Hwy at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.95776900005806, 40.6088350009905]},
#   'line': 'B-Q'},
#  {'objectid': '2',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '15th St & Avenue U at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.95582799955477, 40.59899100093364]},
#   'line': 'B-Q'},
#  {'objectid': '3',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '15th St & Gravesend Neck Rd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9551200002249, 40.595020000759654]},
#   'line': 'B-Q'},
#  {'objectid': '4',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '15th St & Sheepshead Bay Rd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.954223999936, 40.58730200083184]},
#   'line': 'B-Q'},
#  {'objectid': '5',
#   'url': 'http://web.mta.info/nyct/service/',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.96025800029547, 40.57798600098538]},
#   'line': 'B-Q'},
#  {'objectid': '6',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Branch 7 St & Brighton Beach Rd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.96052400057089, 40.577931001322625]},
#   'line': 'B-Q'},
#  {'objectid': '7',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Branch 7 St & Brighton Beach Rd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.96023100018317, 40.577746001029006]},
#   'line': 'B-Q'},
#  {'objectid': '8',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Branch 7 St & Brighton Beach Rd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.96043800015305, 40.577697001130275]},
#   'line': 'B-Q'},
#  {'objectid': '9',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Ocean Pkwy & Brighton Beach Rd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.96789400057325, 40.57642300107101]},
#   'line': 'Q'},
#  {'objectid': '10',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Ocean Pkwy & Brighton Beach Rd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.96759099960158, 40.576445000451336]},
#   'line': 'Q'},
#  {'objectid': '11',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Ocean Pkwy & Brighton Beach Rd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.96787500037775, 40.576209000557355]},
#   'line': 'Q'},
#  {'objectid': '12',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Ocean Pkwy & Brighton Beach Rd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.96756100003365, 40.57623400093167]},
#   'line': 'Q'},
#  {'objectid': '13',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '8th St & Surf Ave at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97687299966972, 40.575499000848396]},
#   'line': 'F-Q'},
#  {'objectid': '14',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '8th St & Surf Ave at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97674700022307, 40.57592900101308]},
#   'line': 'F-Q'},
#  {'objectid': '15',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Stillwell Ave & Mermaid Ave at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98084599950501, 40.57690000134535]},
#   'line': 'D-F-N-Q'},
#  {'objectid': '16',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '9th Ave & New Utrecht Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99448899987257, 40.64633700121817]},
#   'line': 'D'},
#  {'objectid': '17',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 45th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99442299985472, 40.64018500077808]},
#   'line': 'D'},
#  {'objectid': '18',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 45th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99422000043182, 40.64018000098069]},
#   'line': 'D'},
#  {'objectid': '19',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 44th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9944109994909, 40.64136000117219]},
#   'line': 'D'},
#  {'objectid': '20',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 44th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9941880002461, 40.64137900096152]},
#   'line': 'D'},
#  {'objectid': '21',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 50th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99491500048453, 40.63613300097741]},
#   'line': 'D'},
#  {'objectid': '22',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 50th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9947020002238, 40.63613900052338]},
#   'line': 'D'},
#  {'objectid': '23',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 49th St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9948789997417, 40.63641500047355]},
#   'line': 'D'},
#  {'objectid': '24',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 49th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99467300018873, 40.63640500075824]},
#   'line': 'D'},
#  {'objectid': '25',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 55th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99526200010341, 40.63138900082608]},
#   'line': 'D'},
#  {'objectid': '26',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 55th St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9956429999148, 40.63153800051997]},
#   'line': 'D'},
#  {'objectid': '27',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 55th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99528300054382, 40.63170900124219]},
#   'line': 'D'},
#  {'objectid': '28',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 71st St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99919500003303, 40.61883400119433]},
#   'line': 'D'},
#  {'objectid': '29',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 71st St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99923999991759, 40.619133001338305]},
#   'line': 'D'},
#  {'objectid': '30',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 71st St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99899500042902, 40.61877000052378]},
#   'line': 'D'},
#  {'objectid': '31',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 71st St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99883200058711, 40.6188890009745]},
#   'line': 'D'},
#  {'objectid': '32',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 79th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.0008919994665, 40.61285500054176]},
#   'line': 'D'},
#  {'objectid': '33',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 79th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.00072099959921, 40.61284700061145]},
#   'line': 'D'},
#  {'objectid': '34',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '18th Ave & 85th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.001491000569, 40.60760200112182]},
#   'line': 'D'},
#  {'objectid': '35',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '18th Ave & 85th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.00189400049318, 40.60772300097482]},
#   'line': 'D'},
#  {'objectid': '36',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '18th Ave & 85th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.00162800005522, 40.607897001127455]},
#   'line': 'D'},
#  {'objectid': '37',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '20th Ave & 86th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99816400038932, 40.60443900088166]},
#   'line': 'D'},
#  {'objectid': '38',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '20th Ave & 86th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9980069998917, 40.60458700083699]},
#   'line': 'D'},
#  {'objectid': '39',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '20th Ave & 86th St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99849799968783, 40.6046310005965]},
#   'line': 'D'},
#  {'objectid': '40',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '20th Ave & 86th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99834900054789, 40.60478900051507]},
#   'line': 'D'},
#  {'objectid': '41',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Bay Pkwy & 86th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99369600038919, 40.601726001220165]},
#   'line': 'D'},
#  {'objectid': '42',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Bay Pkwy & 86th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99353800042097, 40.60189800117387]},
#   'line': 'D'},
#  {'objectid': '43',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Bay Pkwy & 86th St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99413000010537, 40.60199300109585]},
#   'line': 'D'},
#  {'objectid': '44',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Bay Pkwy & 86th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99394800015628, 40.60215000128454]},
#   'line': 'D'},
#  {'objectid': '45',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '25th Ave & 86th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9869580004091, 40.597889001091715]},
#   'line': 'D'},
#  {'objectid': '46',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '25th Ave & 86th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9872790005634, 40.59810000066808]},
#   'line': 'D'},
#  {'objectid': '47',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '25th Ave & 86th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98711199986317, 40.59775100078925]},
#   'line': 'D'},
#  {'objectid': '48',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '25th Ave & 86th St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98744200051077, 40.59795200062024]},
#   'line': 'D'},
#  {'objectid': '49',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Stillwell Ave & Bay 50th St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98373500008773, 40.5880220010568]},
#   'line': 'D'},
#  {'objectid': '50',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Stillwell Ave & Bay 50th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9834979996632, 40.58806600105337]},
#   'line': 'D'},
#  {'objectid': '51',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Stillwell Ave & Bay 50th St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98379099979309, 40.588305001122556]},
#   'line': 'D'},
#  {'objectid': '52',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Stillwell Ave & Bay 50th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98354300013526, 40.58834800097843]},
#   'line': 'D'},
#  {'objectid': '53',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '8th Ave & 62nd St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.01072599969021, 40.634552000604174]},
#   'line': 'N'},
#  {'objectid': '54',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Fort Hamilton Pkwy & 62nd St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-74.00665799960328, 40.63217900062705]},
#   'line': 'N'},
#  {'objectid': '55',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'New Utrecht Ave & 62nd St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.99682999968425, 40.62560600131959]},
#   'line': 'D-N'},
#  {'objectid': '56',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '18th Ave & 64th St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98940999985166, 40.620062000905534]},
#   'line': 'N'},
#  {'objectid': '57',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '20th Ave & 64th St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98484000011217, 40.617341001073875]},
#   'line': 'N'},
#  {'objectid': '58',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Bay Pkwy & 66th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98208399986588, 40.61298900111904]},
#   'line': 'N'},
#  {'objectid': '59',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '7th St & Kings Hwy at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98057800010078, 40.60510700076654]},
#   'line': 'N'},
#  {'objectid': '60',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '8th St & Avenue U at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97894299952885, 40.59645900059184]},
#   'line': 'N'},
#  {'objectid': '61',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '8th St & 86th St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97822700039235, 40.59272400119584]},
#   'line': 'N'},
#  {'objectid': '62',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '121st St & Jamaica Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.82933199999007, 40.70025400130229]},
#   'line': 'J-Z'},
#  {'objectid': '63',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '121st St & Jamaica Ave at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.82923100020398, 40.70052000103535]},
#   'line': 'J-Z'},
#  {'objectid': '64',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '111th St & Jamaica Blvd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.83704200031487, 40.696771000936984]},
#   'line': 'J'},
#  {'objectid': '65',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '111th St & Jamaica Blvd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.83715599995726, 40.69705500070232]},
#   'line': 'J'},
#  {'objectid': '66',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '104th St & Jamaica Ave at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.84329800036508, 40.69503300049355]},
#   'line': 'J-Z'},
#  {'objectid': '67',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '104th St & Jamaica Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.8432230004546, 40.69526700049504]},
#   'line': 'J-Z'},
#  {'objectid': '68',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Woodhaven Blvd & Jamaica Ave at SW corner',
# ...
#    'coordinates': [-73.98744599980998, 40.69233500054976]},
#   'line': 'A-C-F-R'},
#  {'objectid': '786',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Jay St & Willoughby St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98744300042478, 40.69239300046189]},
#   'line': 'A-C-F-R'},
#  {'objectid': '787',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Jay St & Willoughby St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.9874939995761, 40.692336000842694]},
#   'line': 'A-C-F-R'},
#  {'objectid': '788',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Jay St & Willoughby St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98749100023262, 40.69239400075601]},
#   'line': 'A-C-F-R'},
#  {'objectid': '789',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Hoyt St & Schermerhorn St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98594099947078, 40.68908500061754]},
#   'line': 'A-C-G'},
#  {'objectid': '790',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Bond St & Schermerhorn St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.98421600016393, 40.688396001275585]},
#   'line': 'A-C-G'},
#  {'objectid': '791',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Oxford St & Fulton Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97275999951495, 40.68578900079028]},
#   'line': 'C'},
#  {'objectid': '792',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Oxford St & Fulton Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97289999985651, 40.68555900120916]},
#   'line': 'C'},
#  {'objectid': '793',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Oxford St & Fulton Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97302099989815, 40.685969001131355]},
#   'line': 'C'},
#  {'objectid': '794',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Oxford St & Fulton Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97352599975537, 40.68570000079172]},
#   'line': 'C'},
#  {'objectid': '795',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Oxford St & Fulton Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97330800027531, 40.6860770009335]},
#   'line': 'C'},
#  {'objectid': '796',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Portland Ave & Fulton Ave at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97427799971175, 40.68604100048046]},
#   'line': 'C'},
#  {'objectid': '797',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Portland Ave & Fulton Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97434700032048, 40.68640900089698]},
#   'line': 'C'},
#  {'objectid': '798',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Portland Ave & Fulton Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97451699946798, 40.68611900122114]},
#   'line': 'C'},
#  {'objectid': '799',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Portland Ave & Fulton Ave at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.97460599941192, 40.686553000949395]},
#   'line': 'C'},
#  {'objectid': '800',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Clinton Ave & Fulton Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.96679699983912, 40.68365300070044]},
#   'line': 'C'},
#  {'objectid': '801',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Clinton Ave & Fulton Ave at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.96706900021974, 40.68369500049261]},
#   'line': 'C'},
#  {'objectid': '802',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Nostrand Ave & Fulton St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.94951499982591, 40.68054700115432]},
#   'line': 'A-C'},
#  {'objectid': '803',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Nostrand Ave & Fulton St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.94975299964452, 40.68057200095438]},
#   'line': 'A-C'},
#  {'objectid': '804',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Throop Ave & Fulton St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.94024699963524, 40.68001000080545]},
#   'line': 'A-C'},
#  {'objectid': '805',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Throop Ave & Fulton St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.94048300024578, 40.680057001206364]},
#   'line': 'A-C'},
#  {'objectid': '806',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Utica Ave & Fulton St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.93004400011803, 40.679095001156526]},
#   'line': 'A-C'},
#  {'objectid': '807',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Utica Ave & Fulton St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.92972500040634, 40.679487000732564]},
#   'line': 'A-C'},
#  {'objectid': '808',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Ralph Ave & Fulton St at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.92155199962924, 40.67870200077484]},
#   'line': 'A-C'},
#  {'objectid': '809',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Ralph Ave & Fulton St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.92144200048577, 40.678984001189484]},
#   'line': 'A-C'},
#  {'objectid': '810',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Ralph Ave & Mac Dougal St at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.92187000056835, 40.67916400114647]},
#   'line': 'A-C'},
#  {'objectid': '811',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Hopkinson Ave & Fulton St at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.91373199978516, 40.67859400130624]},
#   'line': 'A-C'},
#  {'objectid': '812',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Hopkinson Ave & Fulton St at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.91365100050982, 40.67831700068249]},
#   'line': 'A-C'},
#  {'objectid': '813',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Fulton St & Van Sinderen Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.90392200051937, 40.678334000847464]},
#   'line': 'A-C-J-L'},
#  {'objectid': '814',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Pennsylvania Ave & Liberty Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.89664499975883, 40.67424200103689]},
#   'line': 'A-C'},
#  {'objectid': '815',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Pennsylvania Ave & Liberty Ave at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.89631200038666, 40.67426800096991]},
#   'line': 'A-C'},
#  {'objectid': '816',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Pennsylvania Ave & Liberty Ave at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.89677599994724, 40.67443000131494]},
#   'line': 'A-C'},
#  {'objectid': '817',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '180th St & Hillside Ave at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.78317899949278, 40.712940000938254]},
#   'line': 'F'},
#  {'objectid': '818',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '180th St & Hillside Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.78327400043251, 40.712669001041526]},
#   'line': 'F'},
#  {'objectid': '819',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '180th St & Hillside Ave at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.7833629997439, 40.71289200058548]},
#   'line': 'F'},
#  {'objectid': '820',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '179th Pl & Hillside Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.7834270000399, 40.71254800063715]},
#   'line': 'F'},
#  {'objectid': '821',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '169th St & Hillside Ave at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.79285300008401, 40.71056300080342]},
#   'line': 'F'},
#  {'objectid': '822',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '169th St & Hillside Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.79276099959564, 40.71096800048277]},
#   'line': 'F'},
#  {'objectid': '823',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '169th St & Hillside Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.79302199947567, 40.710495000849924]},
#   'line': 'F'},
#  {'objectid': '824',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '169th St & Hillside Ave at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.79324800046304, 40.7108300008175]},
#   'line': 'F'},
#  {'objectid': '825',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Parsons Blvd & Hillside Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.80279699999659, 40.70747300091829]},
#   'line': 'F'},
#  {'objectid': '826',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Parsons Blvd & Hillside Ave at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.80299899948717, 40.707873000981024]},
#   'line': 'F'},
#  {'objectid': '827',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Parsons Blvd & Hillside Ave at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.80261100041199, 40.70756300092153]},
#   'line': 'F'},
#  {'objectid': '828',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Sutphin Blvd & Hillside Ave at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.80948100057626, 40.705591001080236]},
#   'line': 'F'},
#  {'objectid': '829',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Sutphin Blvd & Hillside Ave at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.80948899986537, 40.70594500079124]},
#   'line': 'F'},
#  {'objectid': '830',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Sutphin Blvd & Hillside Ave at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.80971700032187, 40.705538000904426]},
#   'line': 'F'},
#  {'objectid': '831',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Van Wyck Blvd & Queens Blvd at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.82011099992044, 40.708068001230046]},
#   'line': 'F'},
#  {'objectid': '832',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Van Wyck Blvd & Queens Blvd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.81977300037678, 40.70931600045191]},
#   'line': 'F'},
#  {'objectid': '833',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '84th Rd & Queens Blvd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.81960100046479, 40.70968100067085]},
#   'line': 'F'},
#  {'objectid': '834',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Union Tpke & Queens Blvd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.83116599992069, 40.7140010008164]},
#   'line': 'E-F'},
#  {'objectid': '835',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '80th Rd & Queens Blvd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.8300109999448, 40.713663001265026]},
#   'line': 'E-F'},
#  {'objectid': '836',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Union Tpke & Queens Blvd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.82991699992932, 40.71407300068592]},
#   'line': 'E-F'},
#  {'objectid': '837',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Union Tpke & Queens Blvd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.83130300014818, 40.713967001105964]},
#   'line': 'E-F'},
#  {'objectid': '838',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '75th Rd & Queens Blvd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.83674300025113, 40.71789500073465]},
#   'line': 'E-F'},
#  {'objectid': '839',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '75th & Queens Blvd at NW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.83791599992833, 40.71906100051211]},
#   'line': 'E-F'},
#  {'objectid': '840',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '75th & Queens Blvd at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.83825699999589, 40.7185740008389]},
#   'line': 'E-F'},
#  {'objectid': '841',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '71st & Queens Blvd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.84403899977785, 40.72110000058624]},
#   'line': 'E-F-M-R'},
#  {'objectid': '842',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '71st & Queens Blvd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.84338899958266, 40.72149000126793]},
#   'line': 'E-F-M-R'},
#  {'objectid': '843',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '67th Ave & Queens Blvd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.85353400011596, 40.7265980010494]},
#   'line': 'M-R'},
#  {'objectid': '844',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '67th Ave & Queens Blvd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.853226000456, 40.72707300076862]},
#   'line': 'M-R'},
#  {'objectid': '845',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '63rd Rd & Queens Blvd at SW corner (exit only)',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.86269899961161, 40.72995300085667]},
#   'line': 'M-R'},
#  {'objectid': '846',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '63rd Rd & Queens Blvd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.86081399943335, 40.729265000582856]},
#   'line': 'M-R'},
#  {'objectid': '847',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Woodhaven Blvd & Queens Blvd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.87033400014576, 40.73304100076268]},
#   'line': 'M-R'},
#  {'objectid': '848',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Woodhaven Blvd & Queens Blvd at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.87098299989292, 40.733354001050536]},
#   'line': 'M-R'},
#  {'objectid': '849',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '59th Ave & Queens Blvd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.86958799977317, 40.7335550009951]},
#   'line': 'M-R'},
#  {'objectid': '850',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '54th St & Queens Blvd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.87688600016183, 40.735888000642326]},
#   'line': 'M-R'},
#  {'objectid': '851',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '54th St & Queens Blvd at NE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.87642400016867, 40.73627700100364]},
#   'line': 'M-R'},
#  {'objectid': '852',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': '54th St & Queens Blvd at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.8771669998173, 40.73607500046235]},
#   'line': 'M-R'},
#  {'objectid': '853',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & Queens Blvd at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.87719099990078, 40.737354001235445]},
#   'line': 'M-R'},
#  {'objectid': '854',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Broadway & Queens Blvd at SW corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.87742399942309, 40.73747700047902]},
#   'line': 'M-R'},
#  {'objectid': '855',
#   'url': 'http://web.mta.info/nyct/service/',
#   'name': 'Elmhurst Ave & Broadway at SE corner',
#   'the_geom': {'type': 'Point',
#    'coordinates': [-73.88113500019222, 40.74172900073593]},
#   'line': 'M-R'}]

# %% [markdown]
# Create new Dataframe for JSON data

# %%
column_names=['Object_ID', 'Name', 'URL','Latitude', 'Longitude']
subway_df=pd.DataFrame(columns=column_names)

# %%
subway_df
# Out:
#    Object_ID                                               Name  \
# 0       1734            Birchall Ave & Sagamore St at NW corner
# 1       1735            Birchall Ave & Sagamore St at NE corner
# 2       1736            Morris Park Ave & 180th St at NW corner
# 3       1737            Morris Park Ave & 180th St at NW corner
# 4       1738                  Boston Rd & 178th St at SW corner
# 62      1796               90th St & Roosevelt Ave at NW corner
# 63      1797               82nd St & Roosevelt Ave at NE corner
# 64      1798               82nd St & Roosevelt Ave at SW corner
# 65      1799               82nd St & Roosevelt Ave at NW corner
# 66      1800               69th St & Roosevelt Ave at NE corner
# 67      1801               69th St & Roosevelt Ave at SW corner
# 68      1802               61st St & Roosevelt Ave at SE corner
# 69      1803               61st St & Roosevelt Ave at NE corner
# 70      1804               61st St & Roosevelt Ave at NE corner
# 71      1805               52nd St & Roosevelt Ave at SW corner
# 72      1806               52nd St & Roosevelt Ave at NW corner
# 73      1807               53rd St & Roosevelt Ave at SE corner
# 74      1808               53rd St & Roosevelt Ave at NE corner
# 75      1809                 46th St & Queens Blvd at SE corner
# 76      1810                 46th St & Queens Blvd at NE corner
# 77      1811                 46th St & Queens Blvd at SW corner
# 78      1812                 46th St & Queens Blvd at NW corner
# 79      1813                 40th St & Queens Blvd at SE corner
# 80      1814                 40th St & Queens Blvd at NE corner
# 81      1815                 40th St & Queens Blvd at SW corner
# 82      1816                 40th St & Queens Blvd at NW corner
# 83      1817                 33rd St & Queens Blvd at SE corner
# 84      1818                 33rd St & Queens Blvd at NE corner
# 85      1819                 33rd St & Queens Blvd at NW corner
# 86      1820                 33rd St & Queens Blvd at SW corner
# 87      1821          Queens Plaza North & 27th St at NW corner
# 88      1822          Queens Plaza South & 27th St at SW corner
# 89      1823                     23rd St & 45th Rd at NW corner
# 90      1824                     23rd St & 45th Rd at SE corner
# 91      1825                     23rd St & 45th Rd at NE corner
# 92      1826                    21st St & 49th Ave at NE corner
# 93      1827                    21st St & 49th Ave at NE corner
# 94      1828                    21st St & 49th Ave at NE corner
# 95      1829                Vernon Blvd & 50th Ave at NE corner
# 96      1830                Vernon Blvd & 50th Ave at NE corner
# 97      1831                     5th Ave & 42nd St at SW corner
#
#                                   URL   Latitude  Longitude
# 0   http://web.mta.info/nyct/service/  40.849169 -73.868356
# 1   http://web.mta.info/nyct/service/  40.849128 -73.868213
# 2   http://web.mta.info/nyct/service/  40.841223 -73.873499
# 3   http://web.mta.info/nyct/service/  40.841453 -73.872892
# 4   http://web.mta.info/nyct/service/  40.840815 -73.879623
# 5   http://web.mta.info/nyct/service/  40.840434 -73.880005
# 6   http://web.mta.info/nyct/service/  40.840354 -73.879833
# 7   http://web.mta.info/nyct/service/  40.840639 -73.879555
# 8   http://web.mta.info/nyct/service/  40.841078 -73.879397
# 9   http://web.mta.info/nyct/service/  40.837325 -73.888048
# 10  http://web.mta.info/nyct/service/  40.837599 -73.887755
# 11  http://web.mta.info/nyct/service/  40.829903 -73.892020
# 12  http://web.mta.info/nyct/service/  40.830369 -73.892015
# 13  http://web.mta.info/nyct/service/  40.824356 -73.892897
# 14  http://web.mta.info/nyct/service/  40.824177 -73.893114
# 15  http://web.mta.info/nyct/service/  40.824358 -73.892724
# 16  http://web.mta.info/nyct/service/  40.822400 -73.896508
# 17  http://web.mta.info/nyct/service/  40.822447 -73.896719
# 67  http://web.mta.info/nyct/service/  40.746148 -73.896396
# 68  http://web.mta.info/nyct/service/  40.745531 -73.903248
# 69  http://web.mta.info/nyct/service/  40.745717 -73.903063
# 70  http://web.mta.info/nyct/service/  40.745692 -73.903234
# 71  http://web.mta.info/nyct/service/  40.743933 -73.913003
# 72  http://web.mta.info/nyct/service/  40.744067 -73.913080
# 73  http://web.mta.info/nyct/service/  40.744453 -73.911282
# 74  http://web.mta.info/nyct/service/  40.744590 -73.911294
# 75  http://web.mta.info/nyct/service/  40.743064 -73.918601
# 76  http://web.mta.info/nyct/service/  40.743217 -73.918564
# 77  http://web.mta.info/nyct/service/  40.743105 -73.918848
# 78  http://web.mta.info/nyct/service/  40.743240 -73.918813
# 79  http://web.mta.info/nyct/service/  40.743710 -73.924161
# 80  http://web.mta.info/nyct/service/  40.743882 -73.924112
# 81  http://web.mta.info/nyct/service/  40.743743 -73.924417
# 82  http://web.mta.info/nyct/service/  40.743911 -73.924385
# 83  http://web.mta.info/nyct/service/  40.744568 -73.931570
# 84  http://web.mta.info/nyct/service/  40.744724 -73.931533
# 85  http://web.mta.info/nyct/service/  40.744594 -73.931829
# 86  http://web.mta.info/nyct/service/  40.744763 -73.931794
# 87  http://web.mta.info/nyct/service/  40.750835 -73.939671
# 88  http://web.mta.info/nyct/service/  40.750302 -73.940245
# 89  http://web.mta.info/nyct/service/  40.746308 -73.945713
# 90  http://web.mta.info/nyct/service/  40.746130 -73.945349
# 91  http://web.mta.info/nyct/service/  40.746232 -73.945322
# 92  http://web.mta.info/nyct/service/  40.742500 -73.948609
# 93  http://web.mta.info/nyct/service/  40.742405 -73.948110
# 94  http://web.mta.info/nyct/service/  40.742422 -73.948195
# 95  http://web.mta.info/nyct/service/  40.742759 -73.953893
# 96  http://web.mta.info/nyct/service/  40.742803 -73.953955
# 97  http://web.mta.info/nyct/service/  40.753409 -73.981130

# %%
for data in json:
    objectid = data['objectid']
    name=data['name']
    url = data['url']
    subway_latlon = data['the_geom']['coordinates']
    subway_lat = subway_latlon[1]
    subway_lon = subway_latlon[0]
    
    subway_df = subway_df.append({'Object_ID': objectid,
                                          'Name':name,
                                          'URL': url,
                                          'Latitude': subway_lat,
                                          'Longitude': subway_lon}, ignore_index=True)

# %%
subway_df.shape
# Out:
# (98, 5)

# %%
subway_df.head()
# Out:
#   Object_ID                                     Name  \
# 0      1734  Birchall Ave & Sagamore St at NW corner
# 1      1735  Birchall Ave & Sagamore St at NE corner
# 2      1736  Morris Park Ave & 180th St at NW corner
# 3      1737  Morris Park Ave & 180th St at NW corner
# 4      1738        Boston Rd & 178th St at SW corner
#
#                                  URL   Latitude  Longitude
# 0  http://web.mta.info/nyct/service/  40.849169 -73.868356
# 1  http://web.mta.info/nyct/service/  40.849128 -73.868213
# 2  http://web.mta.info/nyct/service/  40.841223 -73.873499
# 3  http://web.mta.info/nyct/service/  40.841453 -73.872892
# 4  http://web.mta.info/nyct/service/  40.840815 -73.879623
